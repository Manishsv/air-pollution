# %% [markdown]
# ## Air Quality MVP — Exploration\n\nThis notebook is optional. The primary entrypoint is `python main.py`.\n\nSuggested checks:\n- Inspect `data/processed/static_features.geojson`\n- Inspect `data/outputs/hotspot_recommendations.geojson`\n- Open the Folium HTML maps in `data/outputs/`\n
